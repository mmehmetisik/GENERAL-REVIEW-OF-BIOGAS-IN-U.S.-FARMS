# %% [markdown]
# <div style="background-color: #34495e; border-radius: 35px; padding: 50px 20px; box-shadow: 0px 15px 40px rgba(0, 0, 0, 0.2); border: 5px solid #FFC107;">
#     <div style="max-width: 900px; margin: 0 auto;">
#         <h1 style="font-size: 54px; font-weight: bold; color: #FFC107; text-align: center; font-family: 'Arial'; padding: 15px; background-color: #2c3e50; border-radius: 25px; letter-spacing: 3px; margin-bottom: 25px;">GENERAL REVIEW OF BIOGAS IN U.S. FARMS</h1>
#         <h2 style="font-size: 38px; font-weight: normal; color: #ecf0f1; text-align: center; font-family: 'Georgia'; letter-spacing: 2px; padding: 10px; background-color: #2c3e50; border-radius: 20px; margin-bottom: 40px;">Cattle, Dairy, Poultry, and Swine</h2>
#         <div style="background-image: url('https://www.nationalgrid.com/sites/default/files/styles/content_embedded_image/public/images/Biogas_CowsGrazingInField_640x360.jpg?itok=REI3L5G6'); height: 420px; background-size: cover; background-position: center; border-radius: 30px; box-shadow: 0px 12px 30px rgba(0, 0, 0, 0.15);"></div>
#     </div>
# </div>

# %% [markdown]
# <div style="border: 10px solid #E74C3C; border-radius: 30px; padding: 50px; box-shadow: 10px 10px 25px #34495E; background: linear-gradient(to bottom right, #AED6F1, #E8DAEF);">
#     <h2 style="font-size: 40px; font-weight: bold; color: #8E44AD; text-align: center; border-bottom: 6px solid #F39C12; font-family: 'Arial'; padding: 25px; margin-top: 0; box-shadow: 4px 4px 12px #7D8A99; background-color: #FDEDCD; border-radius: 20px;">🌱 Understanding Biogas Production in the US</h2>
#     <p style="font-size: 20px; font-family: 'Calibri'; line-height: 1.7; padding: 30px; text-align: justify; background-color: #FEF9E7; border-radius: 20px; box-shadow: 3px 3px 8px #BFC9CA;">In the United States, livestock farms are not just significant for food production, but they also hold immense potential for sustainable energy generation. Biogas emerges as one of these energy sources, produced through the fermentation of various animal wastes. This natural gas serves as a potential energy source and plays a pivotal role in reducing greenhouse gas emissions.</p>
#     <ul style="font-size: 20px; font-family: 'Calibri'; padding: 30px; line-height: 1.7; margin-top: 30px; list-style-type: none;">
#         <li>🌍 <strong style="color: #8E44AD; font-size: 21px;">Deep Dive into Biogas Production:</strong> This study aims to delve deeply into livestock farms in the U.S. with biogas production. The dataset provides critical details about these projects, including their location, biogas and energy production, and emission reduction amounts.</li>
#         <li>🔍 <strong style="color: #8E44AD; font-size: 21px;">Identifying Key Contributors:</strong> Through this analysis, we intend to pinpoint which regions, farm types, and technologies are most effective for biogas production. Furthermore, we aim to identify which projects have the highest energy conversion rates and which farm types contribute most efficiently to biogas production.</li>
#         <li>🍃 <strong style="color: #8E44AD; font-size: 21px;">Assessing Environmental Impact:</strong> An integral part of this study will also be to assess the environmental impacts of these projects, enhancing our understanding of how biogas production contributes to energy and sustainability goals in the United States.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="border: 10px solid #2ECC71; border-radius: 30px; padding: 40px; box-shadow: 10px 10px 25px #16A085; background: linear-gradient(to bottom right, #D1F2EB, #E8F8F5);">
#     <h2 style="font-size: 34px; font-weight: bold; color: #0E6655; text-align: center; border-bottom: 5px solid #F1C40F; font-family: 'Arial'; padding: 20px; margin-top: 0; box-shadow: 5px 5px 15px #7D8A99; background-color: #FEF5E7; border-radius: 20px;">📊 Dataset Story</h2>
#     <ul style="font-size: 18px; font-family: 'Calibri'; padding: 30px; line-height: 1.7; list-style-type: none;">
#         <li>📌 <strong style="color: #0E6655;">Project Name:</strong> The name of the biogas project.</li>
#         <li>📍 <strong style="color: #0E6655;">Project Type:</strong> Type of the biogas project.</li>
#         <li>🌆 <strong style="color: #0E6655;">City:</strong> The city where the project is located.</li>
#         <li>🏞️ <strong style="color: #0E6655;">County:</strong> The county where the project is situated.</li>
#         <li>🗺️ <strong style="color: #0E6655;">State:</strong> The state where the project is located.</li>
#         <li>🔬 <strong style="color: #0E6655;">Digester Type:</strong> Type of digester used in the project.</li>
#         <li>🔍 <strong style="color: #0E6655;">Status:</strong> Current status of the project.</li>
#         <li>📅 <strong style="color: #0E6655;">Year Operational:</strong> The year when the project became operational.</li>
#         <li>🐄 <strong style="color: #0E6655;">Animal/Farm Type(s):</strong> Types of animals or farms used in the project.</li>
#         <li>🐄 <strong style="color: #0E6655;">Cattle:</strong> Number of cattle involved.</li>
#         <li>🥛 <strong style="color: #0E6655;">Dairy:</strong> Number of dairy cows involved.</li>
#         <li>🐔 <strong style="color: #0E6655;">Poultry:</strong> Number of poultry involved.</li>
#         <li>🐖 <strong style="color: #0E6655;">Swine:</strong> Number of swine involved.</li>
#         <li>🔄 <strong style="color: #0E6655;">Co-Digestion:</strong> Information on whether co-digestion is being used or not.</li>
#         <li>🌬️ <strong style="color: #0E6655;">Biogas Generation Estimate (cu-ft/day):</strong> Estimated daily biogas production.</li>
#         <li>⚡ <strong style="color: #0E6655;">Electricity Generated (kWh/yr):</strong> Estimated annual electricity generation.</li>
#         <li>💡 <strong style="color: #0E6655;">Biogas End Use(s):</strong> How the produced biogas is utilized.</li>
#         <li>🌿 <strong style="color: #0E6655;">LCFS Pathway?:</strong> Information on the Low Carbon Fuel Standard pathway.</li>
#         <li>🔌 <strong style="color: #0E6655;">Receiving Utility:</strong> The utility company receiving the biogas or electricity.</li>
#         <li>🌍 <strong style="color: #0E6655;">Total Emission Reductions (MTCO2e/yr):</strong> Estimated total emission reduction.</li>
#         <li>🏆 <strong style="color: #0E6655;">Awarded USDA Funding?:</strong> Information on whether the project received USDA funding or not.</li>
#         <li>📊 <strong style="color: #0E6655;">Operational Years:</strong> Number of years the project has been operational.</li>
#         <li>🦓 <strong style="color: #0E6655;">Total_Animals:</strong> Total number of animals involved in the project.</li>
#         <li>💨 <strong style="color: #0E6655;">Biogas_per_Animal (cu-ft/day):</strong> Estimated biogas production per animal.</li>
#         <li>🌱 <strong style="color: #0E6655;">Emission_Reduction_per_Year:</strong> Estimated annual emission reduction per animal.</li>
#         <li>🔋 <strong style="color: #0E6655;">Electricity_to_Biogas_Ratio:</strong> The ratio between electricity generation and biogas production.</li>
#         <li>🗑️ <strong style="color: #0E6655;">Total_Waste_kg/day:</strong> Estimated daily waste production.</li>
#         <li>⚙️ <strong style="color: #0E6655;">Waste_Efficiency:</strong> Efficiency of waste conversion to biogas.</li>
#         <li>🔧 <strong style="color: #0E6655;">Electricity_Efficiency:</strong> Efficiency of biogas conversion to electricity.</li>
#     </ul>
# </div>

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>1 |</span></b> <b>Importing Libraries</b></div>

# %%
# !pip install geopandas matplotlib folium
# Out:
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: folium in /opt/conda/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: fiona>=1.8.19 in /opt/conda/lib/python3.10/site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pandas>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from folium) (2.31.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->folium) (1.26.15)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
import folium

from datetime import datetime
from IPython.display import HTML as html_print
from termcolor import colored
from IPython.display import display

import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="scipy")

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>2 |</span></b> <b>Adjusting Row & Column Settings</b></div>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>3 |</span></b> <b>Loading The Data Set</b></div>

# %%
df = pd.read_excel("/kaggle/input/agstar-livestock-ad-database-combined/agstar-livestock-ad-database-combined.xlsx")

# %%
def print_section_title(title):
    print(colored(title, 'blue', attrs=['bold', 'underline']))
    
def display_head_and_tail(dataframe, head=5):
    display(dataframe.head(head).style.set_caption("Head"))
    display(dataframe.tail(head).style.set_caption("Tail"))

def display_na(dataframe):
    na_df = dataframe.isnull().sum().reset_index()
    na_df.columns = ['Column', 'Number of NA']
    display(na_df.style.set_caption("Number of NA Values"))

def display_quantiles(dataframe):
    quantiles_df = dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
    display(quantiles_df.style.format("{:.2f}").set_caption("Quantiles"))

def check_df(dataframe, head=5):
    print_section_title('Shape')
    print(dataframe.shape)
    print_section_title('Types')
    print(dataframe.dtypes.to_frame('Data Type').style.set_caption("Data Types"))
    print_section_title('Info')
    print(dataframe.info())
    print_section_title('Head & Tail')
    display_head_and_tail(dataframe, head)
    print_section_title('NA Values')
    display_na(dataframe)
    print_section_title('Quantiles')
    display_quantiles(dataframe)

# %%
check_df(df)
# Out:
# Shape
# (526, 26)
# Types
# <pandas.io.formats.style.Styler object at 0x7c78b8a66ef0>
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 26 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Project Name                                    526 non-null    object
#  1   Cluster Name                                    129 non-null    object
#  2   Project Type                                    526 non-null    object
#  3   City                                            525 non-null    object
#  4   County                                          517 non-null    object
#  5   State                                           526 non-null    object
#  6   Digester Type                                   525 non-null    object
#  7   Status                                          526 non-null    object
#  8   Year Operational                                509 non-null    float64
#  9   Animal/Farm Type(s)                             526 non-null    object
#  10  Cattle                                          12 non-null     float64
#  11  Dairy                                           421 non-null    float64
#  12  Poultry                                         13 non-null     float64
#  13  Swine                                           59 non-null     float64
#  14  Co-Digestion                                    135 non-null    object
#  15  Biogas Generation Estimate (cu-ft/day)          232 non-null    float64
#  16  Electricity Generated (kWh/yr)                  242 non-null    object
#  17  Biogas End Use(s)                               518 non-null    object
#  18  LCFS Pathway?                                   86 non-null     object
#  19  System Designer(s)/Developer(s) and Affiliates  503 non-null    object
#  20  Receiving Utility                               252 non-null    object
#  21  Total Emission Reductions (MTCO2e/yr)           399 non-null    float64
#  22  Awarded USDA Funding?                           127 non-null    object
#  23  Sheet                                           526 non-null    object
#  24  Year Shutdown                                   86 non-null     float64
#  25  Reason for Closure                              63 non-null     object
# dtypes: float64(8), object(18)
# memory usage: 107.0+ KB
# None
# Head & Tail
# <style type="text/css">
# </style>
# <table id="T_e6cdb">
#   <caption>Head</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6cdb_level0_col0" class="col_heading level0 col0" >Project Name</th>
#       <th id="T_e6cdb_level0_col1" class="col_heading level0 col1" >Cluster Name</th>
#       <th id="T_e6cdb_level0_col2" class="col_heading level0 col2" >Project Type</th>
#       <th id="T_e6cdb_level0_col3" class="col_heading level0 col3" >City</th>
#       <th id="T_e6cdb_level0_col4" class="col_heading level0 col4" >County</th>
#       <th id="T_e6cdb_level0_col5" class="col_heading level0 col5" >State</th>
#       <th id="T_e6cdb_level0_col6" class="col_heading level0 col6" >Digester Type</th>
#       <th id="T_e6cdb_level0_col7" class="col_heading level0 col7" >Status</th>
#       <th id="T_e6cdb_level0_col8" class="col_heading level0 col8" >Year Operational</th>
#       <th id="T_e6cdb_level0_col9" class="col_heading level0 col9" >Animal/Farm Type(s)</th>
#       <th id="T_e6cdb_level0_col10" class="col_heading level0 col10" >Cattle</th>
#       <th id="T_e6cdb_level0_col11" class="col_heading level0 col11" >Dairy</th>
#       <th id="T_e6cdb_level0_col12" class="col_heading level0 col12" >Poultry</th>
#       <th id="T_e6cdb_level0_col13" class="col_heading level0 col13" >Swine</th>
#       <th id="T_e6cdb_level0_col14" class="col_heading level0 col14" >Co-Digestion</th>
#       <th id="T_e6cdb_level0_col15" class="col_heading level0 col15" >Biogas Generation Estimate (cu-ft/day)</th>
#       <th id="T_e6cdb_level0_col16" class="col_heading level0 col16" >Electricity Generated (kWh/yr)</th>
#       <th id="T_e6cdb_level0_col17" class="col_heading level0 col17" >Biogas End Use(s)</th>
#       <th id="T_e6cdb_level0_col18" class="col_heading level0 col18" >LCFS Pathway?</th>
#       <th id="T_e6cdb_level0_col19" class="col_heading level0 col19" >System Designer(s)/Developer(s) and Affiliates</th>
#       <th id="T_e6cdb_level0_col20" class="col_heading level0 col20" >Receiving Utility</th>
#       <th id="T_e6cdb_level0_col21" class="col_heading level0 col21" >Total Emission Reductions (MTCO2e/yr)</th>
#       <th id="T_e6cdb_level0_col22" class="col_heading level0 col22" >Awarded USDA Funding?</th>
#       <th id="T_e6cdb_level0_col23" class="col_heading level0 col23" >Sheet</th>
#       <th id="T_e6cdb_level0_col24" class="col_heading level0 col24" >Year Shutdown</th>
#       <th id="T_e6cdb_level0_col25" class="col_heading level0 col25" >Reason for Closure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6cdb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6cdb_row0_col0" class="data row0 col0" >Cargill - Sandy River Farm Digester</td>
#       <td id="T_e6cdb_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_e6cdb_row0_col2" class="data row0 col2" >Farm Scale</td>
#       <td id="T_e6cdb_row0_col3" class="data row0 col3" >Morrilton</td>
#       <td id="T_e6cdb_row0_col4" class="data row0 col4" >Conway</td>
#       <td id="T_e6cdb_row0_col5" class="data row0 col5" >AR</td>
#       <td id="T_e6cdb_row0_col6" class="data row0 col6" >Covered Lagoon</td>
#       <td id="T_e6cdb_row0_col7" class="data row0 col7" >Operational</td>
#       <td id="T_e6cdb_row0_col8" class="data row0 col8" >2008.000000</td>
#       <td id="T_e6cdb_row0_col9" class="data row0 col9" >Swine</td>
#       <td id="T_e6cdb_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_e6cdb_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_e6cdb_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_e6cdb_row0_col13" class="data row0 col13" >4200.000000</td>
#       <td id="T_e6cdb_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_e6cdb_row0_col15" class="data row0 col15" >1814400.000000</td>
#       <td id="T_e6cdb_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_e6cdb_row0_col17" class="data row0 col17" >Flared Full-time</td>
#       <td id="T_e6cdb_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_e6cdb_row0_col19" class="data row0 col19" >Martin Construction Resource LLC (formerly RCM) [System Designer, System Design Engineer]; Red Barn Consulting [Project Developer, System Designer]</td>
#       <td id="T_e6cdb_row0_col20" class="data row0 col20" >nan</td>
#       <td id="T_e6cdb_row0_col21" class="data row0 col21" >4482.755303</td>
#       <td id="T_e6cdb_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_e6cdb_row0_col23" class="data row0 col23" >Operational and Construction</td>
#       <td id="T_e6cdb_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_e6cdb_row0_col25" class="data row0 col25" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e6cdb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6cdb_row1_col0" class="data row1 col0" >Butterfield RNG Digester</td>
#       <td id="T_e6cdb_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_e6cdb_row1_col2" class="data row1 col2" >Farm Scale</td>
#       <td id="T_e6cdb_row1_col3" class="data row1 col3" >Buckeye</td>
#       <td id="T_e6cdb_row1_col4" class="data row1 col4" >Maricopa</td>
#       <td id="T_e6cdb_row1_col5" class="data row1 col5" >AZ</td>
#       <td id="T_e6cdb_row1_col6" class="data row1 col6" >Mixed Plug Flow</td>
#       <td id="T_e6cdb_row1_col7" class="data row1 col7" >Operational</td>
#       <td id="T_e6cdb_row1_col8" class="data row1 col8" >2022.000000</td>
#       <td id="T_e6cdb_row1_col9" class="data row1 col9" >Dairy</td>
#       <td id="T_e6cdb_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_e6cdb_row1_col11" class="data row1 col11" >11760.000000</td>
#       <td id="T_e6cdb_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_e6cdb_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_e6cdb_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_e6cdb_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_e6cdb_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_e6cdb_row1_col17" class="data row1 col17" >Pipeline Gas</td>
#       <td id="T_e6cdb_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_e6cdb_row1_col19" class="data row1 col19" >Avolta [Project Developer]; DVO, Inc. (formerly GHD, Inc.) [System Designer, System Design Engineer]</td>
#       <td id="T_e6cdb_row1_col20" class="data row1 col20" >Southwest Gas</td>
#       <td id="T_e6cdb_row1_col21" class="data row1 col21" >14030.128975</td>
#       <td id="T_e6cdb_row1_col22" class="data row1 col22" >Yes</td>
#       <td id="T_e6cdb_row1_col23" class="data row1 col23" >Operational and Construction</td>
#       <td id="T_e6cdb_row1_col24" class="data row1 col24" >nan</td>
#       <td id="T_e6cdb_row1_col25" class="data row1 col25" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e6cdb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6cdb_row2_col0" class="data row2 col0" >Caballero Dairy Farms Digester</td>
#       <td id="T_e6cdb_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_e6cdb_row2_col2" class="data row2 col2" >Farm Scale</td>
#       <td id="T_e6cdb_row2_col3" class="data row2 col3" >Eloy</td>
#       <td id="T_e6cdb_row2_col4" class="data row2 col4" >Pinal</td>
#       <td id="T_e6cdb_row2_col5" class="data row2 col5" >AZ</td>
#       <td id="T_e6cdb_row2_col6" class="data row2 col6" >Unknown or Unspecified</td>
#       <td id="T_e6cdb_row2_col7" class="data row2 col7" >Construction</td>
#       <td id="T_e6cdb_row2_col8" class="data row2 col8" >2022.000000</td>
#       <td id="T_e6cdb_row2_col9" class="data row2 col9" >Dairy</td>
#       <td id="T_e6cdb_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_e6cdb_row2_col11" class="data row2 col11" >8800.000000</td>
#       <td id="T_e6cdb_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_e6cdb_row2_col13" class="data row2 col13" >nan</td>
#       <td id="T_e6cdb_row2_col14" class="data row2 col14" >nan</td>
#       <td id="T_e6cdb_row2_col15" class="data row2 col15" >nan</td>
#       <td id="T_e6cdb_row2_col16" class="data r
# <style type="text/css">
# </style>
# <table id="T_f157a">
#   <caption>Tail</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f157a_level0_col0" class="col_heading level0 col0" >Project Name</th>
#       <th id="T_f157a_level0_col1" class="col_heading level0 col1" >Cluster Name</th>
#       <th id="T_f157a_level0_col2" class="col_heading level0 col2" >Project Type</th>
#       <th id="T_f157a_level0_col3" class="col_heading level0 col3" >City</th>
#       <th id="T_f157a_level0_col4" class="col_heading level0 col4" >County</th>
#       <th id="T_f157a_level0_col5" class="col_heading level0 col5" >State</th>
#       <th id="T_f157a_level0_col6" class="col_heading level0 col6" >Digester Type</th>
#       <th id="T_f157a_level0_col7" class="col_heading level0 col7" >Status</th>
#       <th id="T_f157a_level0_col8" class="col_heading level0 col8" >Year Operational</th>
#       <th id="T_f157a_level0_col9" class="col_heading level0 col9" >Animal/Farm Type(s)</th>
#       <th id="T_f157a_level0_col10" class="col_heading level0 col10" >Cattle</th>
#       <th id="T_f157a_level0_col11" class="col_heading level0 col11" >Dairy</th>
#       <th id="T_f157a_level0_col12" class="col_heading level0 col12" >Poultry</th>
#       <th id="T_f157a_level0_col13" class="col_heading level0 col13" >Swine</th>
#       <th id="T_f157a_level0_col14" class="col_heading level0 col14" >Co-Digestion</th>
#       <th id="T_f157a_level0_col15" class="col_heading level0 col15" >Biogas Generation Estimate (cu-ft/day)</th>
#       <th id="T_f157a_level0_col16" class="col_heading level0 col16" >Electricity Generated (kWh/yr)</th>
#       <th id="T_f157a_level0_col17" class="col_heading level0 col17" >Biogas End Use(s)</th>
#       <th id="T_f157a_level0_col18" class="col_heading level0 col18" >LCFS Pathway?</th>
#       <th id="T_f157a_level0_col19" class="col_heading level0 col19" >System Designer(s)/Developer(s) and Affiliates</th>
#       <th id="T_f157a_level0_col20" class="col_heading level0 col20" >Receiving Utility</th>
#       <th id="T_f157a_level0_col21" class="col_heading level0 col21" >Total Emission Reductions (MTCO2e/yr)</th>
#       <th id="T_f157a_level0_col22" class="col_heading level0 col22" >Awarded USDA Funding?</th>
#       <th id="T_f157a_level0_col23" class="col_heading level0 col23" >Sheet</th>
#       <th id="T_f157a_level0_col24" class="col_heading level0 col24" >Year Shutdown</th>
#       <th id="T_f157a_level0_col25" class="col_heading level0 col25" >Reason for Closure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f157a_level0_row0" class="row_heading level0 row0" >521</th>
#       <td id="T_f157a_row0_col0" class="data row0 col0" >Quantum Dairy Digester</td>
#       <td id="T_f157a_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_f157a_row0_col2" class="data row0 col2" >Farm Scale</td>
#       <td id="T_f157a_row0_col3" class="data row0 col3" >Weyauwega</td>
#       <td id="T_f157a_row0_col4" class="data row0 col4" >Waupaca</td>
#       <td id="T_f157a_row0_col5" class="data row0 col5" >WI</td>
#       <td id="T_f157a_row0_col6" class="data row0 col6" >Mixed Plug Flow</td>
#       <td id="T_f157a_row0_col7" class="data row0 col7" >Shut down</td>
#       <td id="T_f157a_row0_col8" class="data row0 col8" >2005.000000</td>
#       <td id="T_f157a_row0_col9" class="data row0 col9" >Dairy</td>
#       <td id="T_f157a_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_f157a_row0_col11" class="data row0 col11" >1200.000000</td>
#       <td id="T_f157a_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_f157a_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_f157a_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_f157a_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_f157a_row0_col16" class="data row0 col16" >3350700</td>
#       <td id="T_f157a_row0_col17" class="data row0 col17" >Cogeneration</td>
#       <td id="T_f157a_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_f157a_row0_col19" class="data row0 col19" >DVO, Inc. (formerly GHD, Inc.) [Project Developer, System Designer, System Design Engineer]</td>
#       <td id="T_f157a_row0_col20" class="data row0 col20" >WE Energies, Inc.</td>
#       <td id="T_f157a_row0_col21" class="data row0 col21" >nan</td>
#       <td id="T_f157a_row0_col22" class="data row0 col22" >Yes</td>
#       <td id="T_f157a_row0_col23" class="data row0 col23" >Shutdown</td>
#       <td id="T_f157a_row0_col24" class="data row0 col24" >2012.000000</td>
#       <td id="T_f157a_row0_col25" class="data row0 col25" >Clint Fandrich indicated that the farm suffered a catastrophic fire in 2012. The owners see great value in the digester and wil look to bring the system back online in the coming years.</td>
#     </tr>
#     <tr>
#       <th id="T_f157a_level0_row1" class="row_heading level0 row1" >522</th>
#       <td id="T_f157a_row1_col0" class="data row1 col0" >Stencil Farm Digester</td>
#       <td id="T_f157a_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_f157a_row1_col2" class="data row1 col2" >Farm Scale</td>
#       <td id="T_f157a_row1_col3" class="data row1 col3" >Denmark</td>
#       <td id="T_f157a_row1_col4" class="data row1 col4" >Brown</td>
#       <td id="T_f157a_row1_col5" class="data row1 col5" >WI</td>
#       <td id="T_f157a_row1_col6" class="data row1 col6" >Horizontal Plug Flow</td>
#       <td id="T_f157a_row1_col7" class="data row1 col7" >Shut down</td>
#       <td id="T_f157a_row1_col8" class="data row1 col8" >2002.000000</td>
#       <td id="T_f157a_row1_col9" class="data row1 col9" >Dairy</td>
#       <td id="T_f157a_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_f157a_row1_col11" class="data row1 col11" >1000.000000</td>
#       <td id="T_f157a_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_f157a_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_f157a_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_f157a_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_f157a_row1_col16" class="data row1 col16" >946080</td>
#       <td id="T_f157a_row1_col17" class="data row1 col17" >Electricity</td>
#       <td id="T_f157a_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_f157a_row1_col19" class="data row1 col19" >Martin Construction Resource LLC (formerly RCM) [Project Developer, System Designer, System Design Engineer]</td>
#       <td id="T_f157a_row1_col20" class="data row1 col20" >Wisconsin Public Service Corporation</td>
#       <td id="T_f157a_row1_col21" class="data row1 col21" >nan</td>
#       <td id="T_f157a_row1_col22" class="data row1 col22" >nan</td>
#       <td id="T_f157a_row1_col23" class="data row1 col23" >Shutdown</td>
#       <td id="T_f157a_row1_col24" class="data row1 col24" >2010.000000</td>
#       <td id="T_f157a_row1_col25" class="data row1 col25" >The digester experienced difficulty in keeping within the target operational temperature range, so the project switched to composting.</td>
#     </tr>
#     <tr>
#       <th id="T_f157a_level0_row2" class="row_heading level0 row2" >523</th>
#       <td id="T_f157a_row2_col0" class="data row2 col0" >Tinedale Farms Digester</td>
#       <td id="T_f157a_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_f157a_row2_col2" class="data row2 col2" >Farm Scale</td>
#       <td id="T_f157a_row2_col3" class="data row2 col3" >Wrightstown</td>
#       <td id="T_f157a_row2_col4" class="data row2 col4" >Jackson</td>
#       <td id="T_f157a_row2_col5" class="data row2 col5" >WI</td>
#       <td id="T_f157a_row2_col6" class="data row2 col6" >Fixed Film/Attached Media</td>
#       <td id="T_f157a_row2_col7" class="data row2 col7" >Shut down</td>
#       <td id="T_f157a_row2_col8" class="data row2 col8" >1999.000000</td>
#       <td id="T_f157a_row2_col9" class="data row2 col9" >Dairy</td>
#       <td id="T_f157a_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_f157a_row2_col11" class="data row2 col11" >1800.000000</td>
#       <td id="T_f157a_row2_col12" class="data row2 col12" >nan</td>
#       <t
# NA Values
# <style type="text/css">
# </style>
# <table id="T_16102">
#   <caption>Number of NA Values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16102_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_16102_level0_col1" class="col_heading level0 col1" >Number of NA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16102_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16102_row0_col0" class="data row0 col0" >Project Name</td>
#       <td id="T_16102_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16102_row1_col0" class="data row1 col0" >Cluster Name</td>
#       <td id="T_16102_row1_col1" class="data row1 col1" >397</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16102_row2_col0" class="data row2 col0" >Project Type</td>
#       <td id="T_16102_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16102_row3_col0" class="data row3 col0" >City</td>
#       <td id="T_16102_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16102_row4_col0" class="data row4 col0" >County</td>
#       <td id="T_16102_row4_col1" class="data row4 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16102_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_16102_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_16102_row6_col0" class="data row6 col0" >Digester Type</td>
#       <td id="T_16102_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_16102_row7_col0" class="data row7 col0" >Status</td>
#       <td id="T_16102_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_16102_row8_col0" class="data row8 col0" >Year Operational</td>
#       <td id="T_16102_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_16102_row9_col0" class="data row9 col0" >Animal/Farm Type(s)</td>
#       <td id="T_16102_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_16102_row10_col0" class="data row10 col0" >Cattle</td>
#       <td id="T_16102_row10_col1" class="data row10 col1" >514</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_16102_row11_col0" class="data row11 col0" >Dairy</td>
#       <td id="T_16102_row11_col1" class="data row11 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_16102_row12_col0" class="data row12 col0" >Poultry</td>
#       <td id="T_16102_row12_col1" class="data row12 col1" >513</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_16102_row13_col0" class="data row13 col0" >Swine</td>
#       <td id="T_16102_row13_col1" class="data row13 col1" >467</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_16102_row14_col0" class="data row14 col0" >Co-Digestion</td>
#       <td id="T_16102_row14_col1" class="data row14 col1" >391</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_16102_row15_col0" class="data row15 col0" >Biogas Generation Estimate (cu-ft/day)</td>
#       <td id="T_16102_row15_col1" class="data row15 col1" >294</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_16102_row16_col0" class="data row16 col0" >Electricity Generated (kWh/yr)</td>
#       <td id="T_16102_row16_col1" class="data row16 col1" >284</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_16102_row17_col0" class="data row17 col0" >Biogas End Use(s)</td>
#       <td id="T_16102_row17_col1" class="data row17 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_16102_row18_col0" class="data row18 col0" >LCFS Pathway?</td>
#       <td id="T_16102_row18_col1" class="data row18 col1" >440</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_16102_row19_col0" class="data row19 col0" >System Designer(s)/Developer(s) and Affiliates</td>
#       <td id="T_16102_row19_col1" class="data row19 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_16102_row20_col0" class="data row20 col0" >Receiving Utility</td>
#       <td id="T_16102_row20_col1" class="data row20 col1" >274</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_16102_row21_col0" class="data row21 col0" >Total Emission Reductions (MTCO2e/yr)</td>
#       <td id="T_16102_row21_col1" class="data row21 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_16102_row22_col0" class="data row22 col0" >Awarded USDA Funding?</td>
#       <td id="T_16102_row22_col1" class="data row22 col1" >399</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_16102_row23_col0" class="data row23 col0" >Sheet</td>
#       <td id="T_16102_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_16102_row24_col0" class="data row24 col0" >Year Shutdown</td>
#       <td id="T_16102_row24_col1" class="data row24 col1" >440</td>
#     </tr>
#     <tr>
#       <th id="T_16102_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_16102_row25_col0" class="data row25 col0" >Reason for Closure</td>
#       <td id="T_16102_row25_col1" class="data row25 col1" >463</td>
#     </tr>
#   </tbody>
# </table>
# Quantiles
# <style type="text/css">
# </style>
# <table id="T_aed8a">
#   <caption>Quantiles</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aed8a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_aed8a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_aed8a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_aed8a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_aed8a_level0_col4" class="col_heading level0 col4" >0%</th>
#       <th id="T_aed8a_level0_col5" class="col_heading level0 col5" >5%</th>
#       <th id="T_aed8a_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_aed8a_level0_col7" class="col_heading level0 col7" >95%</th>
#       <th id="T_aed8a_level0_col8" class="col_heading level0 col8" >99%</th>
#       <th id="T_aed8a_level0_col9" class="col_heading level0 col9" >100%</th>
#       <th id="T_aed8a_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aed8a_level0_row0" class="row_heading level0 row0" >Year Operational</th>
#       <td id="T_aed8a_row0_col0" class="data row0 col0" >509.00</td>
#       <td id="T_aed8a_row0_col1" class="data row0 col1" >2012.53</td>
#       <td id="T_aed8a_row0_col2" class="data row0 col2" >8.57</td>
#       <td id="T_aed8a_row0_col3" class="data row0 col3" >1972.00</td>
#       <td id="T_aed8a_row0_col4" class="data row0 col4" >1972.00</td>
#       <td id="T_aed8a_row0_col5" class="data row0 col5" >1998.40</td>
#       <td id="T_aed8a_row0_col6" class="data row0 col6" >2012.00</td>
#       <td id="T_aed8a_row0_col7" class="data row0 col7" >2023.00</td>
#       <td id="T_aed8a_row0_col8" class="data row0 col8" >2023.00</td>
#       <td id="T_aed8a_row0_col9" class="data row0 col9" >2023.00</td>
#       <td id="T_aed8a_row0_col10" class="data row0 col10" >2023.00</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row1" class="row_heading level0 row1" >Cattle</th>
#       <td id="T_aed8a_row1_col0" class="data row1 col0" >12.00</td>
#       <td id="T_aed8a_row1_col1" class="data row1 col1" >7509.17</td>
#       <td id="T_aed8a_row1_col2" class="data row1 col2" >12764.58</td>
#       <td id="T_aed8a_row1_col3" class="data row1 col3" >30.00</td>
#       <td id="T_aed8a_row1_col4" class="data row1 col4" >30.00</td>
#       <td id="T_aed8a_row1_col5" class="data row1 col5" >85.00</td>
#       <td id="T_aed8a_row1_col6" class="data row1 col6" >2450.00</td>
#       <td id="T_aed8a_row1_col7" class="data row1 col7" >33400.00</td>
#       <td id="T_aed8a_row1_col8" class="data row1 col8" >38680.00</td>
#       <td id="T_aed8a_row1_col9" class="data row1 col9" >40000.00</td>
#       <td id="T_aed8a_row1_col10" class="data row1 col10" >40000.00</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row2" class="row_heading level0 row2" >Dairy</th>
#       <td id="T_aed8a_row2_col0" class="data row2 col0" >421.00</td>
#       <td id="T_aed8a_row2_col1" class="data row2 col1" >4133.01</td>
#       <td id="T_aed8a_row2_col2" class="data row2 col2" >5152.30</td>
#       <td id="T_aed8a_row2_col3" class="data row2 col3" >30.00</td>
#       <td id="T_aed8a_row2_col4" class="data row2 col4" >30.00</td>
#       <td id="T_aed8a_row2_col5" class="data row2 col5" >320.00</td>
#       <td id="T_aed8a_row2_col6" class="data row2 col6" >2500.00</td>
#       <td id="T_aed8a_row2_col7" class="data row2 col7" >10700.00</td>
#       <td id="T_aed8a_row2_col8" class="data row2 col8" >32000.00</td>
#       <td id="T_aed8a_row2_col9" class="data row2 col9" >39000.00</td>
#       <td id="T_aed8a_row2_col10" class="data row2 col10" >39000.00</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row3" class="row_heading level0 row3" >Poultry</th>
#       <td id="T_aed8a_row3_col0" class="data row3 col0" >13.00</td>
#       <td id="T_aed8a_row3_col1" class="data row3 col1" >229923.08</td>
#       <td id="T_aed8a_row3_col2" class="data row3 col2" >315447.95</td>
#       <td id="T_aed8a_row3_col3" class="data row3 col3" >33000.00</td>
#       <td id="T_aed8a_row3_col4" class="data row3 col4" >33000.00</td>
#       <td id="T_aed8a_row3_col5" class="data row3 col5" >55200.00</td>
#       <td id="T_aed8a_row3_col6" class="data row3 col6" >120000.00</td>
#       <td id="T_aed8a_row3_col7" class="data row3 col7" >780000.00</td>
#       <td id="T_aed8a_row3_col8" class="data row3 col8" >1116000.00</td>
#       <td id="T_aed8a_row3_col9" class="data row3 col9" >1200000.00</td>
#       <td id="T_aed8a_row3_col10" class="data row3 col10" >1200000.00</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row4" class="row_heading level0 row4" >Swine</th>
#       <td id="T_aed8a_row4_col0" class="data row4 col0" >59.00</td>
#       <td id="T_aed8a_row4_col1" class="data row4 col1" >24796.98</td>
#       <td id="T_aed8a_row4_col2" class="data row4 col2" >45830.49</td>
#       <td id="T_aed8a_row4_col3" class="data row4 col3" >10.00</td>
#       <td id="T_aed8a_row4_col4" class="data row4 col4" >10.00</td>
#       <td id="T_aed8a_row4_col5" class="data row4 col5" >599.50</td>
#       <td id="T_aed8a_row4_col6" class="data row4 col6" >8640.00</td>
#       <td id="T_aed8a_row4_col7" class="data row4 col7" >107100.00</td>
#       <td id="T_aed8a_row4_col8" class="data row4 col8" >228064.00</td>
#       <td id="T_aed8a_row4_col9" class="data row4 col9" >239200.00</td>
#       <td id="T_aed8a_row4_col10" class="data row4 col10" >239200.00</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row5" class="row_heading level0 row5" >Biogas Generation Estimate (cu-ft/day)</th>
#       <td id="T_aed8a_row5_col0" class="data row5 col0" >232.00</td>
#       <td id="T_aed8a_row5_col1" class="data row5 col1" >312757.60</td>
#       <td id="T_aed8a_row5_col2" class="data row5 col2" >443393.85</td>
#       <td id="T_aed8a_row5_col3" class="data row5 col3" >5000.00</td>
#       <td id="T_aed8a_row5_col4" class="data row5 col4" >5000.00</td>
#       <td id="T_aed8a_row5_col5" class="data row5 col5" >22550.00</td>
#       <td id="T_aed8a_row5_col6" class="data row5 col6" >200000.00</td>
#       <td id="T_aed8a_row5_col7" class="data row5 col7" >1022500.00</td>
#       <td id="T_aed8a_row5_col8" class="data row5 col8" >2510410.94</td>
#       <td id="T_aed8a_row5_col9" class="data row5 col9" >3454500.00</td>
#       <td id="T_aed8a_row5_col10" class="data row5 col10" >3454500.00</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row6" class="row_heading level0 row6" >Total Emission Reductions (MTCO2e/yr)</th>
#       <td id="T_aed8a_row6_col0" class="data row6 col0" >399.00</td>
#       <td id="T_aed8a_row6_col1" class="data row6 col1" >35127.56</td>
#       <td id="T_aed8a_row6_col2" class="data row6 col2" >47354.39</td>
#       <td id="T_aed8a_row6_col3" class="data row6 col3" >4.22</td>
#       <td id="T_aed8a_row6_col4" class="data row6 col4" >4.22</td>
#       <td id="T_aed8a_row6_col5" class="data row6 col5" >1675.65</td>
#       <td id="T_aed8a_row6_col6" class="data row6 col6" >19321.48</td>
#       <td id="T_aed8a_row6_col7" class="data row6 col7" >97901.16</td>
#       <td id="T_aed8a_row6_col8" class="data row6 col8" >279948.73</td>
#       <td id="T_aed8a_row6_col9" class="data row6 col9" >390000.01</td>
#       <td id="T_aed8a_row6_col10" class="data row6 col10" >390000.01</td>
#     </tr>
#     <tr>
#       <th id="T_aed8a_level0_row7" class="row_heading level0 row7" >Year Shutdown</th>
#       <td id="T_aed8a_row7_col0" class="data row7 col0" >86.00</td>
#       <td id="T_aed8a_row7_col1" class="data row7 col1" >2011.81</td>
#       <td id="T_aed8a_row7_col2" class="data row7 col2" >4.70</td>
#       <td id="T_aed8a_row7_col3" class="data row7 col3" >2000.00</td>
#       <td id="T_aed8a_row7_col4" class="data row7 col4" >2000.00</td>
#       <td id="T_aed8a_row7_col5" class="data row7 col5" >2004.25</td>
#       <td id="T_aed8a_row7_col6" class="data row7 col6" >2011.00</td>
#       <td id="T_aed8a_row7_col7" class="data row7 col7" >2019.00</td>
#       <td id="T_aed8a_row7_col8" class="data row7 col8" >2022.00</td>
#       <td id="T_aed8a_row7_col9" class="data ro

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>4 |</span></b> <b>Feature Engineering</b></div>

# %%
# The names of the states were replaced by their full names.

state_mappings = {
    "AL": "Alabama",
    "AK": "Alaska",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District of Columbia",
    "FL": "Florida",
    "GA": "Georgia",
    "GU": "Guam",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "MP": "Northern Mariana Islands",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PA": "Pennsylvania",
    "PR": "Puerto Rico",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "TT": "Trust Territories",
    "UT": "Utah",
    "VT": "Vermont",
    "VI": "Virgin Islands",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"
}

df["State"] = df["State"].map(state_mappings)

# %%
df = df.dropna(subset=['Cattle', 'Dairy', 'Poultry', 'Swine'], how='all')

# %%
# We have removed variables from the data set that we cannot use.

drop_columns=["Cluster Name", "System Designer(s)/Developer(s) and Affiliates", "Sheet", "Reason for Closure"]

# %%
df.drop(drop_columns, axis =1, inplace=True)

# %%
# We replaced the categorical expression in the variable Electricity Generated (kWh/yr) with "Project Name", NaN.

df['Electricity Generated (kWh/yr)'].replace('Project Name', np.nan, inplace=True)

# %%
# We changed the type of the variable Electricity Generated (kWh/yr) from categorical to numeric.

df['Electricity Generated (kWh/yr)'] = pd.to_numeric(df['Electricity Generated (kWh/yr)'], errors='coerce')

# %%
# NaN observations on farms without livestock were replaced by 0.

df["Cattle"] = df["Cattle"].apply(lambda x: x if pd.notna(x) and np.isreal(x) else '0')

df["Dairy"] = df["Dairy"].apply(lambda x: x if pd.notna(x) and np.isreal(x) else '0')

df["Poultry"] = df["Poultry"].apply(lambda x: x if pd.notna(x) and np.isreal(x) else '0')

df["Swine"] = df["Swine"].apply(lambda x: x if pd.notna(x) and np.isreal(x) else '0')

# %%
# If the observations in these variables are filled with NaN if there is no information, we replaced those observations with the No-Info variable.

columns_to_fill = ['Awarded USDA Funding?', 'Digester Type', 'LCFS Pathway?', "Biogas End Use(s)"]

df[columns_to_fill] = df[columns_to_fill].fillna('No-Info')

# %%
# We have replaced the observations in the following variables with Yes if there is information in them and No-Info otherwise.

df["Co-Digestion"] = df["Co-Digestion"].apply(lambda x: 'Yes' if pd.notna(x) else 'No-Info')

df["Receiving Utility"] = df["Receiving Utility"].apply(lambda x: 'Yes' if pd.notna(x) else 'No-Info')

# %%
# We discarded rows whose 'City' and 'County' columns are NaN at the same time.

df.dropna(subset=['City', 'County'], how='all', inplace= True)

# %%
# We have completed the missing County information.

def fill_county(row):
    city = row['City']
    state = row['State']

    county_dict = {
        'Thompson,Connecticut': 'Windham County',
        'Coventry,Connecticut': 'Tolland County',
        'Pocomoke City,Maryland': 'Worcester County',
        'Columbia,Missouri': 'Boone County',
        'Browning,Missouri': 'Linn County',
        'Sumter,South Carolina': 'Sumter County',
        'Dalhart,Texas': 'Dallam County',
        'Milford,Utah': 'Beaver County'
    }
    
    return county_dict.get(f"{city},{state}", row['County'])

df['County'] = df.apply(fill_county, axis=1)

# %%
# We have completed the location information for the farm at index 192.

df.loc[192, 'County'] = 'Kings County'
df.loc[192, 'State'] = 'California'

# %%
# We discarded the 489th index of the Year Operational variable because it was empty. The plant here is both shutdown and the year of shutdown is missing. so this plant does not carry useful information for analysis.

df.drop(index=489, inplace= True)

# %%
df.isnull().sum()
# Out:
# Project Name                                0
# Project Type                                0
# City                                        0
# County                                      0
# State                                       0
# Digester Type                               0
# Status                                      0
# Year Operational                           15
# Animal/Farm Type(s)                         0
# Cattle                                      0
# Dairy                                       0
# Poultry                                     0
# Swine                                       0
# Co-Digestion                                0
# Biogas Generation Estimate (cu-ft/day)    262
# Electricity Generated (kWh/yr)            257
# Biogas End Use(s)                           0
# LCFS Pathway?                               0
# Receiving Utility                           0
# Total Emission Reductions (MTCO2e/yr)      93
# Awarded USDA Funding?                       0
# Year Shutdown                             414
# dtype: int64

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>5 |</span></b> <b>Feature Extraction</b></div>

# %%
# Present Day 

current_year = 2023

# %%
# We calculated how many years the farm has been running and added it to the dataset as a new variable.

df["Operational Years"] = current_year - df["Year Operational"]

# %%
# Here, if the year of operation of the farm is less than 0, this indicates that the plant has not been commissioned yet, so we need to replace these negative values with 0. 
# In the 'Operational Years' column, we replaced the negative values with 0. Our aim is to emphasise that this plant has not been commissioned yet, i.e. it is not running.

df.loc[df['Operational Years'] < 0, 'Operational Years'] = 0

# %%
# We have used the information of this variable and it is no longer needed. We dropped it from the data set.

df.drop("Year Shutdown", axis=1, inplace = True)

# %%
# Filter conditions based on "Biogas End Use(s)"
conditions = [
    df["Biogas End Use(s)"] == "Flared Full-time",
    df["Biogas End Use(s)"] == "CNG",
    df["Biogas End Use(s)"] == "Boiler/Furnace fuel",
    df["Biogas End Use(s)"] == "Boiler/Furnace fuel; CNG",
]

# Combining the conditions
combined_conditions = np.logical_or.reduce(conditions)

# Replacing NaN values with 0 for the specified rows in 'Electricity Generated (kWh/yr)'
df.loc[combined_conditions, 'Electricity Generated (kWh/yr)'] = df.loc[combined_conditions, 'Electricity Generated (kWh/yr)'].fillna(0)

# Displaying the rows where changes were made
df[combined_conditions][['Biogas End Use(s)', 'Electricity Generated (kWh/yr)']].head()

# Our aim is to say that farms with this information do not convert gas into electricity.
# Out:
#            Biogas End Use(s)  Electricity Generated (kWh/yr)
# 0           Flared Full-time                           0.000
# 4                        CNG                           0.000
# 8                        CNG                           0.000
# 14  Boiler/Furnace fuel; CNG                           0.000
# 15                       CNG                           0.000

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder


label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le


imputer = KNNImputer(n_neighbors=5)
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)


for column, encoder in label_encoders.items():
    df[column] = encoder.inverse_transform(df[column].astype(int))


missing_values_after = df.isnull().sum()
missing_values_after[missing_values_after > 0]
# Out:
# Series([], dtype: int64)

# %%
df.isnull().sum()
# Out:
# Project Name                              0
# Project Type                              0
# City                                      0
# County                                    0
# State                                     0
# Digester Type                             0
# Status                                    0
# Year Operational                          0
# Animal/Farm Type(s)                       0
# Cattle                                    0
# Dairy                                     0
# Poultry                                   0
# Swine                                     0
# Co-Digestion                              0
# Biogas Generation Estimate (cu-ft/day)    0
# Electricity Generated (kWh/yr)            0
# Biogas End Use(s)                         0
# LCFS Pathway?                             0
# Receiving Utility                         0
# Total Emission Reductions (MTCO2e/yr)     0
# Awarded USDA Funding?                     0
# Operational Years                         0
# dtype: int64

# %%
df['Cattle'] = df['Cattle'].astype('float64')
df['Dairy'] = df['Dairy'].astype('float64')
df['Poultry'] = df['Poultry'].astype('float64')
df['Swine'] = df['Swine'].astype('float64')

df[['Cattle', 'Dairy', 'Poultry', 'Swine']].dtypes
# Out:
# Cattle     float64
# Dairy      float64
# Poultry    float64
# Swine      float64
# dtype: object

# %%
# 1. Total Number of Animals

df['Total_Animals'] = df['Cattle'] + df['Dairy'] + df['Poultry'] + df['Swine']

# %%
# 2. Calculation of the amount of Biogas Production per Animal of each plant

df['Biogas_per_Animal (cu-ft/day)'] = df['Biogas Generation Estimate (cu-ft/day)'] / df['Total_Animals']


df[['Biogas Generation Estimate (cu-ft/day)', 'Total_Animals', 'Biogas_per_Animal (cu-ft/day)']].head()
# Out:
#    Biogas Generation Estimate (cu-ft/day)  Total_Animals  \
# 0                             1814400.000       4200.000
# 1                              109486.000      11760.000
# 2                               94500.000       8800.000
# 3                             3454500.000      30000.000
# 4                              852545.200      10000.000
#
#    Biogas_per_Animal (cu-ft/day)
# 0                        432.000
# 1                          9.310
# 2                         10.739
# 3                        115.150
# 4                         85.255

# %%
# 3. Emission Reduction by Operational Years

df['Emission_Reduction_per_Year'] = df['Total Emission Reductions (MTCO2e/yr)'] / df['Operational Years']

# %%
# We will assume that facilities whose aim is inf have not made Emission_Reduction.

df['Emission_Reduction_per_Year'].replace([np.inf, -np.inf], 0, inplace=True)

# %%
# 4. Biogas to Electricity Conversion Efficiency Analysis of Plants.

df['Electricity_to_Biogas_Ratio'] = df['Electricity Generated (kWh/yr)'] / df['Biogas Generation Estimate (cu-ft/day)']

# %%
df.head()
# Out:
#                             Project Name          Project Type       City  \
# 0    Cargill - Sandy River Farm Digester            Farm Scale  Morrilton
# 1               Butterfield RNG Digester            Farm Scale    Buckeye
# 2         Caballero Dairy Farms Digester            Farm Scale       Eloy
# 3  Green Gas Partners Stanfield Digester  Centralized/Regional   Maricopa
# 4                  Paloma Dairy Digester            Farm Scale  Gila Bend
#
#      County     State           Digester Type        Status  Year Operational  \
# 0    Conway  Arkansas          Covered Lagoon   Operational          2008.000
# 1  Maricopa   Arizona         Mixed Plug Flow   Operational          2022.000
# 2     Pinal   Arizona  Unknown or Unspecified  Construction          2022.000
# 3     Pinal   Arizona            Complete Mix   Operational          2018.000
# 4  Maricopa   Arizona            Complete Mix   Operational          2021.000
#
#   Animal/Farm Type(s)  Cattle     Dairy  Poultry    Swine Co-Digestion  \
# 0               Swine   0.000     0.000    0.000 4200.000      No-Info
# 1               Dairy   0.000 11760.000    0.000    0.000      No-Info
# 2               Dairy   0.000  8800.000    0.000    0.000      No-Info
# 3               Dairy   0.000 30000.000    0.000    0.000      No-Info
# 4               Dairy   0.000 10000.000    0.000    0.000      No-Info
#
#    Biogas Generation Estimate (cu-ft/day)  Electricity Generated (kWh/yr)  \
# 0                             1814400.000                           0.000
# 1                              109486.000                      389698.200
# 2                               94500.000                     2813080.400
# 3                             3454500.000                     2760336.000
# 4                              852545.200                           0.000
#
#   Biogas End Use(s) LCFS Pathway? Receiving Utility  \
# 0  Flared Full-time       No-Info           No-Info
# 1      Pipeline Gas       No-Info               Yes
# 2      Pipeline Gas       No-Info           No-Info
# 3      Pipeline Gas       No-Info               Yes
# 4               CNG       No-Info               Yes
#
#    Total Emission Reductions (MTCO2e/yr) Awarded USDA Funding?  \
# 0                               4482.755               No-Info
# 1                              14030.129                   Yes
# 2                              98999.890               No-Info
# 3                             337499.626               No-Info
# 4                             100569.493               No-Info
#
#    Operational Years  Total_Animals  Biogas_per_Animal (cu-ft/day)  \
# 0             15.000       4200.000                        432.000
# 1              1.000      11760.000                          9.310
# 2              1.000       8800.000                         10.739
# 3              5.000      30000.000                        115.150
# 4              2.000      10000.000                         85.255
#
#    Emission_Reduction_per_Year  Electricity_to_Biogas_Ratio
# 0                      298.850                        0.000
# 1                    14030.129                        3.559
# 2                    98999.890                       29.768
# 3                    67499.925                        0.799
# 4                    50284.747                        0.000

# %% [markdown]
# <div style="background-color: #f8f5fc; padding: 50px; border-radius: 25px; border: 10px double #AD1457; box-shadow: 0 5px 20px 0 rgba(0, 0, 0, 0.2);">
#     <h2 style="font-size: 40px; font-weight: bold; color: #880E4F; text-align: center; font-family: 'Arial'; padding: 35px 0; margin-top: 25px; border-top: 8px solid #FFC107; border-bottom: 8px solid #FFC107; text-shadow: 1px 1px 4px #b39ddb;">🐄 Manure Production in US Livestock 🐓</h2>
#     <ul style="font-size: 24px; font-family: 'Arial'; padding: 30px 50px; color: #212121; line-height: 2.8; background-color: #f3e5f5; border-radius: 20px; box-shadow: 0 4px 10px 0 rgba(0, 0, 0, 0.1);">
#         <li>🐄 <strong style="color: #6A1B9A; font-size: 26px; text-decoration: underline;">Cattle (Dry Cow):</strong> Averages 1,000 lbs (453.6 kg) with a Manure Quantity of 81.4 lbs (36.9 kg).</li>
#         <li>🐄 <strong style="color: #6A1B9A; font-size: 26px; text-decoration: underline;">Dairy (Holstein Cow):</strong> Averages 1,500 lbs (680 kg) with a Manure Quantity of 150 lbs (68 kg).</li>
#         <li>🐓 <strong style="color: #6A1B9A; font-size: 26px; text-decoration: underline;">Poultry (Mixed Egg and Meat Chicken):</strong> Averages 7.7 lbs (3.5 kg) with a Manure Quantity of 0.62 lbs (0.28 kg).</li>
#         <li>🐖 <strong style="color: #6A1B9A; font-size: 26px; text-decoration: underline;">Swine (Finisher Pig):</strong> Averages 150 lbs (68 kg) with a Manure Quantity of 12.6 lbs (5.7 kg).</li>
#     </ul>
#     <p style="font-size: 28px; color: #333; text-align: center; font-family: 'Arial'; padding: 30px; border-top: 5px dashed #AD1457; margin-top: 35px; background-color: #ede7f6; border-radius: 20px; box-shadow: 0 4px 10px 0 rgba(0, 0, 0, 0.1);">📊 <strong style="color: #6A1B9A; text-decoration: underline;">Total Waste (kg/day)</strong> = C × Number of Cattle + D × Number of Dairy + P × Number of Poultry + S × Number of Swine</p>
# </div>

# %%
# Using the amount of waste per animal, we calculated the total amount of waste for each facility.

df['Total_Waste_kg/day'] = (df['Cattle'] * 20) + \
                           (df['Dairy'] * 34) + \
                           (df['Poultry'] * 0.09) + \
                           (df['Swine'] * 5)

# İlk 5 satırı gösterelim
df[['Cattle', 'Dairy', 'Poultry', 'Swine', 'Total_Waste_kg/day']].head()
# Out:
#    Cattle     Dairy  Poultry    Swine  Total_Waste_kg/day
# 0   0.000     0.000    0.000 4200.000           21000.000
# 1   0.000 11760.000    0.000    0.000          399840.000
# 2   0.000  8800.000    0.000    0.000          299200.000
# 3   0.000 30000.000    0.000    0.000         1020000.000
# 4   0.000 10000.000    0.000    0.000          340000.000

# %%
# We create the Waste Efficiency variable.  It shows how much biogas is produced per kilogram of waste for each plant.

df['Waste_Efficiency'] = df['Biogas Generation Estimate (cu-ft/day)'] / df['Total_Waste_kg/day']

# %%
# We create the Electricity Efficiency variable. it shows how much electricity each facility generates per kilogram of waste.

df['Electricity_Efficiency'] = df['Electricity Generated (kWh/yr)'] / df['Total_Waste_kg/day']

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>6 |</span></b> <b>Project Count by State</b></div>

# %%
df_state_projects = df['State'].value_counts()

plt.figure(figsize=(25,8))
df_state_projects.sort_values(ascending=False).plot(kind='bar', color='skyblue', alpha=0.8)

plt.title('Project Count by State', weight='bold', fontsize=18)
plt.ylabel('Number of Projects', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(rotation=90, weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)

for i, value in enumerate(df_state_projects.sort_values(ascending=False)):
    plt.text(i, value + 1, str(value), ha='center', va='bottom', weight='bold', fontsize=12)

plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Project Count by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>7 |</span></b> <b>Top 10 Project Count by County</b></div>

# %%
df_county_projects = df['County'].value_counts().head(10)

plt.figure(figsize=(25,8))
df_county_projects.sort_values(ascending=False).plot(kind='bar', color='lightcoral', alpha=0.8)

plt.title('Top 10 Project Count by County', weight='bold', fontsize=18)
plt.ylabel('Number of Projects', weight='bold', fontsize=14)
plt.xlabel('Counties', weight='bold', fontsize=14)
plt.xticks(rotation=90, weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)

for i, value in enumerate(df_county_projects.sort_values(ascending=False)):
    plt.text(i, value + 0.2, str(value), ha='center', va='bottom', weight='bold', fontsize=12)

plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Top 10 Project Count by County.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>8 |</span></b> <b>Top 10 Project Count by City</b></div>

# %%
df_city_projects = df['City'].value_counts().head(10)

plt.figure(figsize=(25,8))
df_city_projects.sort_values(ascending=False).plot(kind='bar', color='lightgreen', alpha=0.8)

plt.title('Top 10 Project Count by City', weight='bold', fontsize=18)
plt.ylabel('Number of Projects', weight='bold', fontsize=14)
plt.xlabel('Cities', weight='bold', fontsize=14)
plt.xticks(rotation=90, weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)

for i, value in enumerate(df_city_projects.sort_values(ascending=False)):
    plt.text(i, value + 0.2, str(value), ha='center', va='bottom', weight='bold', fontsize=12)

plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Top 10 Project Count by City.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>9 |</span></b> <b>Distribution by Project Type</b></div>

# %%
plt.figure(figsize=(15,10))
df_project_type = df['Project Type'].value_counts()

explode = [0.05 for _ in range(len(df_project_type))]
colors = sns.color_palette("pastel")

df_project_type.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, textprops={'fontsize': 14, 'weight': 'bold'})

plt.title('Distribution by Project Type', weight='bold', fontsize=18)
plt.ylabel('')
plt.savefig('Distribution by Project Type.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>10 |</span></b> <b>Distribution by Project Status</b></div>

# %%
plt.figure(figsize=(15,10))
df_project_status = df['Status'].value_counts()

explode = [0.05 for _ in range(len(df_project_status))]
colors = sns.color_palette("Set3")

df_project_status.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, textprops={'fontsize': 14, 'weight': 'bold'})

plt.title('Distribution by Project Status', weight='bold', fontsize=18)
plt.ylabel('')
plt.savefig('Distribution by Project Status.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>11 |</span></b> <b>Distribution of Projects Based on USDA Funding</b></div>

# %%
plt.figure(figsize=(15,10))
df_usda_funding = df['Awarded USDA Funding?'].value_counts()

explode = [0.05 for _ in range(len(df_usda_funding))]
colors = sns.color_palette("husl")

df_usda_funding.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, textprops={'fontsize': 14, 'weight': 'bold'})

# Title
plt.title('Distribution of Projects Based on USDA Funding', weight='bold', fontsize=18)
plt.ylabel('')
plt.savefig('Distribution of Projects Based on USDA Funding.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>12 |</span></b> <b>Total Electricity Production by Project Type</b></div>

# %%
project_type_electricity = df.groupby('Project Type')['Electricity Generated (kWh/yr)'].sum()
explode = [0.1] * len(project_type_electricity)
colors = sns.color_palette("pastel", len(project_type_electricity))

plt.figure(figsize=(15, 8))
project_type_electricity.plot(kind='pie', explode=explode, colors=colors, autopct='%1.1f%%', startangle=140, 
                              textprops={'fontsize': 14, 'weight': 'bold'})
plt.title('Total Electricity Production by Project Type', fontsize=16, weight='bold')
plt.ylabel('')  
plt.tight_layout()
plt.savefig('Total Electricity Production by Project Type.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>13 |</span></b> <b>Total Animal Count by State</b></div>

# %%
state_animals = df.groupby('State')['Total_Animals'].sum()

sorted_state_animals = state_animals.sort_values(ascending=False)

plt.figure(figsize=(25, 8))
sorted_state_animals.plot(kind='bar', color='lightgreen')
plt.title('Total Animal Count by State', fontsize=16, weight='bold')
plt.ylabel('Number of Animals', fontsize=14, weight='bold')
plt.xlabel('State', fontsize=14, weight='bold')
plt.xticks(rotation=90, weight='bold')
plt.tight_layout()
plt.savefig('Total Animal Count by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>14 |</span></b> <b>Biogas Production by State</b></div>

# %%
df_biogas_production = df.groupby('State')['Biogas Generation Estimate (cu-ft/day)'].sum().sort_values(ascending=False)
plt.figure(figsize=(25,8))

df_biogas_production.plot(kind='bar', color='lightcoral', alpha=0.8)

plt.title('Biogas Production by State', weight='bold', fontsize=18)
plt.ylabel('Biogas Production (cu-ft/day)', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(rotation=90, weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)

plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Biogas Production by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>15 |</span></b> <b>Electricity Production by State</b></div>

# %%
plt.figure(figsize=(25,8))
df_electricity_production = df.groupby('State')['Electricity Generated (kWh/yr)'].sum().sort_values(ascending=False)

df_electricity_production.plot(kind='bar', color='lightgreen', alpha=0.8)

plt.title('Electricity Production by State', weight='bold', fontsize=18)
plt.ylabel('Electricity Production (kWh/yr)', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(rotation=90, weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)

plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Electricity Production by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>16 |</span></b> <b>Biogas Production by Project Type</b></div>

# %%
animal_types = df['Project Type'].unique()
biogas_by_animal = df.groupby('Project Type')['Biogas Generation Estimate (cu-ft/day)'].sum().loc[animal_types]

plt.figure(figsize=(20,8))
biogas_by_animal.sort_values().plot(kind='barh', color=sns.color_palette("muted"), alpha=0.8)

plt.title('Biogas Production by Project Type', weight='bold', fontsize=18)
plt.xlabel('Biogas Production (cu-ft/day)', weight='bold', fontsize=14)
plt.ylabel('Project Types', weight='bold', fontsize=14)
plt.yticks(weight='bold', fontsize=12)
plt.xticks(weight='bold', fontsize=12)

plt.grid(axis='x')

plt.tight_layout()
plt.savefig('Biogas Production by Project Type.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>17 |</span></b> <b>Biogas Production by Digester Type</b></div>

# %%
biogas_by_digester = df.groupby('Digester Type')['Biogas Generation Estimate (cu-ft/day)'].sum()

plt.figure(figsize=(20,8))
biogas_by_digester.sort_values().plot(kind='barh', color='mediumpurple', alpha=0.8)

plt.title('Biogas Production by Digester Type', weight='bold', fontsize=18)
plt.xlabel('Biogas Production (cu-ft/day)', weight='bold', fontsize=14)
plt.ylabel('Digester Types', weight='bold', fontsize=14)
plt.yticks(weight='bold', fontsize=12)
plt.xticks(weight='bold', fontsize=12)

plt.grid(axis='x')

plt.tight_layout()
plt.savefig('Biogas Production by Digester Type.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>18 |</span></b> <b>Number of Projects Operational by Year</b></div>

# %%
df_yearly_projects = df['Year Operational'].value_counts().sort_index()

plt.figure(figsize=(25,8))
df_yearly_projects.plot(kind='line', marker='o', color='orange', linewidth=2.5)

plt.title('Number of Projects Operational by Year', weight='bold', fontsize=20)
plt.ylabel('Number of Projects', weight='bold', fontsize=16)
plt.xlabel('Year', weight='bold', fontsize=16)
plt.xticks(rotation=45, weight='bold', fontsize=14)
plt.yticks(weight='bold', fontsize=14)

plt.tight_layout()
plt.savefig('Number of Projects Operational by Year.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>19 |</span></b> <b>Total Biogas Production Over Years</b></div>

# %%
df_total_biogas_yearly = df.groupby('Year Operational')['Biogas Generation Estimate (cu-ft/day)'].sum()

plt.figure(figsize=(25,8))
df_total_biogas_yearly.plot(kind='area', color='skyblue', alpha=0.7)

plt.title('Total Biogas Production Over Years', weight='bold', fontsize=18)
plt.ylabel('Total Biogas Production (cu-ft/day)', weight='bold', fontsize=14)
plt.xlabel('Year', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)

plt.tight_layout()
plt.savefig('Total Biogas Production Over Years.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>20 |</span></b> <b>Yearly Biogas Production by State</b></div>

# %%
df_biogas_stacked = df.groupby(['Year Operational', 'State'])['Biogas Generation Estimate (cu-ft/day)'].sum().unstack().fillna(0)

sorted_columns = df_biogas_stacked.sum(axis=0).sort_values(ascending=False).index
df_biogas_stacked_sorted = df_biogas_stacked[sorted_columns]

plt.figure(figsize=(25,8))
df_biogas_stacked_sorted.plot(kind='bar', stacked=True, colormap='tab20', figsize=(20,10))

plt.title('Yearly Biogas Production by State', weight='bold', fontsize=18)
plt.ylabel('Total Biogas Production (cu-ft/day)', weight='bold', fontsize=14)
plt.xlabel('Year', weight='bold', fontsize=14)
plt.legend(title='States', fontsize=10, loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)

plt.tight_layout()
plt.savefig('Yearly Biogas Production by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>21 |</span></b> <b>Cattle Count by State</b></div>

# %%
cattle_by_state = df.groupby('State')['Cattle'].sum().sort_values(ascending=False)

plt.figure(figsize=(25,8))
cattle_by_state.plot(kind='bar', color='lightblue')

plt.title('Cattle Count by State', weight='bold', fontsize=18)
plt.ylabel('Number of Cattle', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)

plt.tight_layout()
plt.savefig('Cattle Count by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>22 |</span></b> <b>Dairy Count by State</b></div>

# %%
dairy_by_state = df.groupby('State')['Dairy'].sum().sort_values(ascending=False)

plt.figure(figsize=(25,8))
dairy_by_state.plot(kind='bar', color='lightcoral')

plt.title('Dairy Count by State', weight='bold', fontsize=18)
plt.ylabel('Number of Dairy Cattle', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)

plt.tight_layout()
plt.savefig('Dairy Count by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>23 |</span></b> <b>Poultry Count by State</b></div>

# %%
poultry_by_state = df.groupby('State')['Poultry'].sum().sort_values(ascending=False)

plt.figure(figsize=(25,8))
poultry_by_state.plot(kind='bar', color='lightgreen')

plt.title('Poultry Count by State', weight='bold', fontsize=18)
plt.ylabel('Number of Poultry', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)

plt.tight_layout()
plt.savefig('Poultry Count by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>24 |</span></b> <b>Swine Count by State</b></div>

# %%
swine_by_state = df.groupby('State')['Swine'].sum().sort_values(ascending=False)

plt.figure(figsize=(25,8))
swine_by_state.plot(kind='bar', color='lightpink')

plt.title('Swine Count by State', weight='bold', fontsize=18)
plt.ylabel('Number of Swine', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)

plt.tight_layout()
plt.savefig('Swine Count by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>25 |</span></b> <b>Distribution of Biogas End Uses</b></div>

# %%
biogas_end_uses = df['Biogas End Use(s)'].str.split(',', expand=True).stack().str.strip().value_counts()

plt.figure(figsize=(25,8))
biogas_end_uses.plot(kind='bar', color='lightblue')

plt.title('Distribution of Biogas End Uses', weight='bold', fontsize=18)
plt.ylabel('Count', weight='bold', fontsize=14)
plt.xlabel('Biogas End Uses', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)

plt.tight_layout()
plt.savefig('Distribution of Biogas End Uses.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>26 |</span></b> <b>Distribution of Projects by LCFS Pathway</b></div>

# %%
lcfs_pathway_counts = df['LCFS Pathway?'].value_counts()

explode = (0.1, 0)

plt.figure(figsize=(15, 10))
lcfs_pathway_counts.plot(kind='pie', autopct=lambda p: '{:.1f}% ({:,.0f})'.format(p, (p/100)*lcfs_pathway_counts.sum()), 
                         startangle=90, colors=sns.color_palette("pastel"), explode=explode, textprops={'weight': 'bold'})

plt.title('Distribution of Projects by LCFS Pathway', weight='bold', fontsize=16)
plt.ylabel('') 
plt.tight_layout()
plt.savefig('Distribution of Projects by LCFS Pathway.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>27 |</span></b> <b>Biogas Production Comparison Based on Co-Digestion</b></div>

# %%
biogas_by_codigestion = df.groupby('Co-Digestion')['Biogas Generation Estimate (cu-ft/day)'].mean()

explode = (0.1, 0)  

plt.figure(figsize=(15, 8))
biogas_by_codigestion.plot(kind='pie', autopct=lambda p: '{:.1f}% ({:,.0f} cu-ft/day)'.format(p, (p/100)*biogas_by_codigestion.sum()), 
                           startangle=90, colors=sns.color_palette("pastel"), explode=explode, textprops={'weight': 'bold'})

plt.title('Biogas Production Comparison Based on Co-Digestion', weight='bold', fontsize=16)
plt.ylabel('') 
plt.tight_layout()
plt.savefig('Biogas Production Comparison Based on Co-Digestion.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>28 |</span></b> <b>Project Counts by Receiving Utility</b></div>

# %%
receiving_utility_counts = df['Receiving Utility'].value_counts()

explode = [0.1] * len(receiving_utility_counts)

plt.figure(figsize=(15, 8))
receiving_utility_counts.plot(kind='pie', autopct=lambda p: '{:.1f}% ({:,.0f} projects)'.format(p, (p/100)*receiving_utility_counts.sum()), 
                              startangle=90, colors=sns.color_palette("pastel", len(receiving_utility_counts)), explode=explode, textprops={'weight': 'bold'})

plt.title('Project Counts by Receiving Utility', weight='bold', fontsize=16)
plt.ylabel('') 
plt.tight_layout()
plt.savefig('Project Counts by Receiving Utility.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>29 |</span></b> <b>Distribution of Projects by Number of Operational Years</b></div>

# %%
operational_years = (df['Year Operational'].max() - df['Year Operational']) + 1
operational_years_distribution = operational_years.value_counts()

plt.figure(figsize=(25,8))
operational_years_distribution.sort_values(ascending=False).plot(kind='bar', color='lightgreen')

plt.title('Distribution of Projects by Number of Operational Years', weight='bold', fontsize=16)
plt.ylabel('Number of Projects', weight='bold', fontsize=14)
plt.xlabel('Number of Operational Years', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=0)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Distribution of Projects by Number of Operational Years.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>30 |</span></b> <b>USDA Funding vs. Biogas Production</b></div>

# %%
biogas_total_by_usda_funding = df.groupby('Awarded USDA Funding?')['Biogas Generation Estimate (cu-ft/day)'].sum()

colors = ['lightcoral', 'lightblue']
explode = (0.1, 0) 

plt.figure(figsize=(15,8))
biogas_total_by_usda_funding.plot(kind='pie', explode=explode, colors=colors, autopct='%1.1f%%', 
                                 startangle=140, textprops={'fontsize': 12, 'weight': 'bold'})
plt.title('USDA Funding vs. Biogas Production', weight='bold', fontsize=16)
plt.ylabel('')

plt.tight_layout()
plt.savefig('USDA Funding vs. Biogas Production.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>31 |</span></b> <b>Annual Emission Reduction Comparison by State</b></div>

# %%
emission_by_state = df.groupby('State')['Total Emission Reductions (MTCO2e/yr)'].sum()

plt.figure(figsize=(25,8))
emission_by_state.sort_values(ascending=False).plot(kind='bar', color='lightsalmon', grid=True)

plt.title('Annual Emission Reduction Comparison by State', weight='bold', fontsize=18)
plt.ylabel('Emission Reduction (MTCO2e/yr)', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)

plt.tight_layout()
plt.savefig('Annual Emission Reduction Comparison by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>32 |</span></b> <b>Distribution of Electricity to Biogas Ratio by State</b></div>

# %%
electricity_biogas_ratio_by_state = df.groupby('State')['Electricity_to_Biogas_Ratio'].mean()

plt.figure(figsize=(25,8))
electricity_biogas_ratio_by_state.sort_values(ascending=False).plot(kind='bar', color='lightblue')

plt.title('Distribution of Electricity to Biogas Ratio by State', weight='bold', fontsize=18)
plt.ylabel('Electricity to Biogas Ratio', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12, rotation=90)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Distribution of Electricity to Biogas Ratio by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>33 |</span></b> <b>Total Daily Waste by State</b></div>

# %%
waste_by_state = df.groupby('State')['Total_Waste_kg/day'].sum()

plt.figure(figsize=(25,8))
waste_by_state.sort_values(ascending=False).plot(kind='bar', color='lightgreen')

plt.title('Total Daily Waste by State', weight='bold', fontsize=18)
plt.ylabel('Total Daily Waste (kg/day)', weight='bold', fontsize=14)
plt.xlabel('States', weight='bold', fontsize=14)
plt.xticks(rotation=90, weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.grid(axis='y')

plt.tight_layout()
plt.savefig('Total Daily Waste by State.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>34 |</span></b> <b>Correlation Analysis Results</b></div>

# %%
correlation_biogas_animals = df[['Biogas Generation Estimate (cu-ft/day)', 'Total_Animals']].corr().iloc[0, 1]

correlation_electricity_biogas = df[['Electricity Generated (kWh/yr)', 'Biogas Generation Estimate (cu-ft/day)']].corr().iloc[0, 1]

correlation_waste_biogas = df[['Total_Waste_kg/day', 'Biogas Generation Estimate (cu-ft/day)']].corr().iloc[0, 1]

correlations = {
    'Biogas & Total Animals': correlation_biogas_animals,
    'Electricity & Biogas': correlation_electricity_biogas,
    'Waste & Biogas': correlation_waste_biogas
}

plt.figure(figsize=(15, 8))
plt.bar(correlations.keys(), correlations.values(), color=['blue', 'green', 'red'])
plt.ylabel('Correlation Coefficient')
plt.title('Correlation Analysis Results')
plt.ylim(-1, 1)
plt.axhline(0, color='black', linewidth=0.5)
plt.tight_layout()
plt.savefig('Correlation Analysis Results.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>35 |</span></b> <b>Total Waste Production by Animal Type</b></div>

# %%
animal_types_corrected = ['Cattle', 'Dairy', 'Poultry', 'Swine']

total_waste_per_animal_type_corrected = df[animal_types_corrected].multiply(df['Total_Waste_kg/day'], axis=0).sum()

plt.figure(figsize=(20, 8))
total_waste_per_animal_type_corrected.sort_values().plot(kind='barh', color='lightseagreen')
plt.title('Total Waste Production by Animal Type', weight='bold', fontsize=16)
plt.xlabel('Total Waste (kg)', weight='bold', fontsize=14)
plt.ylabel('Animal Types', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.tight_layout()
plt.savefig('Total Waste Production by Animal Type.png')
plt.show()

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>36 |</span></b> <b>Biogas Project Status Map in the USA</b></div>

# %%
# Download the GeoJSON file for US states
url = "https://raw.githubusercontent.com/PublicaMundi/MappingAPI/master/data/geojson/us-states.json"
states_geo = gpd.read_file(url)

state_status_counts = df.groupby(['State', 'Status']).size().unstack().fillna(0)

# Calculate the center coordinates for the states
states_geo['center'] = states_geo['geometry'].centroid
states_points = states_geo.copy()
states_points.set_geometry("center", inplace=True)

# Create the map
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

colors = {
    "Shut down": "red",
    "Operational": "green",
    "Construction": "orange"
}

for idx, row in states_points.iterrows():
    state_name = row['name']
    for status, color in colors.items():
        count = state_status_counts.loc[state_name, status] if state_name in state_status_counts.index else 0
        if count > 0:
            folium.Marker(
                location=(row['center'].y, row['center'].x),
                icon=folium.Icon(color=color, icon="info-sign"),
                popup=f"{state_name}<br>{status}: {count}"
            ).add_to(m)

# Add a legend displaying color information (moved to the top right corner)
legend_html = '''
<div style="position: fixed; 
            top: 10px; right: 10px; 
            width: 150px; height: 90px; 
            border:2px solid grey; z-index:9999;
            font-size:14px;">
    &nbsp;<b>Status</b><br>
    &nbsp;<i class="fa fa-map-marker fa-2x" style="color:red"></i>&nbsp;Shut down<br>
    &nbsp;<i class="fa fa-map-marker fa-2x" style="color:green"></i>&nbsp;Operational<br>
    &nbsp;<i class="fa fa-map-marker fa-2x" style="color:orange"></i>&nbsp;Construction<br>
</div>
'''

m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
# /tmp/ipykernel_20/2352219098.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   states_geo['center'] = states_geo['geometry'].centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_203e570d110c172e64746a41252cdc43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#             top: 10px; right: 10px;
#             width: 150px; height: 90px;
#             border:2px solid grey; z-index:9999;
#             font-size:14px;&quot;&gt;
#     &amp;nbsp;&lt;b&gt;Status&lt;/b&gt;&lt;br&gt;
#     &amp;nbsp;&lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp;Shut down&lt;br&gt;
#     &amp;nbsp;&lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt;&amp;nbsp;Operational&lt;br&gt;
#     &amp;nbsp;&lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt;&amp;nbsp;Construction&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_203e570d110c172e64746a41252cdc43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_203e570d110c172e64746a41252cdc43 = L.map(
#                 &quot;map_203e570d110c172e64746a41252cdc43&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd9fbe857d4b40a5dfc389cee4773a91 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_203e570d110c172e64746a41252cdc43);
#
#
#             var marker_2c6221c0ef2a41383593300fd27e7cb4 = L.marker(
#                 [34.29339257053982, -111.6632955488151],
#                 {}
#             ).addTo(map_203e570d110c172e64746a41252cdc43);
#
#
#             var icon_bc762401d63436a3dfd642b6c133c03c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c6221c0ef2a41383593300fd27e7cb4.setIcon(icon_bc762401d63436a3dfd642b6c133c03c);
#
#
#         var popup_4d1e2c11c6f7c062d6ba3412a06fe919 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5884f20498d209cc2b3acd47cfd2457 = $(`&lt;div id=&quot;html_e5884f20498d209cc2b3acd47cfd2457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona&lt;br&gt;Operational: 5.0&lt;/div&gt;`)[0];
#                 popup_4d1e2c11c6f7c062d6ba3412a06fe919.setContent(html_e5884f20498d209cc2b3acd47cfd2457);
#
#
#
#         marker_2c6221c0ef2a41383593300fd27e7cb4.bindPopup(popup_4d1e2c11c6f7c062d6ba3412a06fe919)
#         ;
#
#
#
#
#             var marker_f132292e27a51399529c2242fdf907dc = L.marker(
#                 [34.29339257053982, -111.6632955488151],
#                 {}
#             ).addTo(map_203e570d110c172e64746a41252cdc43);
#
#
#             var icon_355494b34eebfb859b586d01dbd80076 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f132292e27a51399529c2242fdf907dc.setIcon(icon_355494b34eebfb859b586d01dbd80076);
#
#
#         var popup_8a485882fd9d28f81dc9b547ce8bd298 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9567bfd0456e86d12deb8ff8b21bb701 = $(`&lt;div id=&quot;html_9567bfd0456e86d12deb8ff8b21bb701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona&lt;br&gt;Construction: 2.0&lt;/div&gt;`)[0];
#                 popup_8a485882fd9d28f81dc9b547ce8bd298.setContent(html_9567bfd0456e86d12deb8ff8b21bb701);
#
#
#
#         marker_f132292e27a51399529c2242fdf907dc.bindPopup(popup_8a485882fd9d28f81dc9b547ce8bd298)
#         ;
#
#
#
#
#             var marker_2bbd4d400658e53155334e1020afdffb = L.marker(
#                 [34.89824915294627, -92.44092031324395],
#                 {}
#             ).addTo(map_203e570d110c172e64746a41252cdc43);
#
#
#             var icon_9cc9b8bf7014c41d73674d71f6ae489f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bbd4d400658e53155334e1020afdffb.setIcon(icon_9cc9b8bf7014c41d73674d71f6ae489f);
#
#
#         var popup_92c890fd73de32123542d457ddd77181 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41a753857fef9d7715226060099198ff = $(`&lt;di

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>37 |</span></b> <b>Analysis Table</b></div>

# %%
state_grouped = df.groupby('State').agg(
    Total_Projects=pd.NamedAgg(column='Project Name', aggfunc='count'),
    Operational_Projects=pd.NamedAgg(column='Status', aggfunc=lambda x: (x == 'Operational').sum()),
    Avg_Operational_Years=pd.NamedAgg(column='Operational Years', aggfunc='mean'),
    Total_Animals=pd.NamedAgg(column='Total_Animals', aggfunc='sum'),
    Cattle=pd.NamedAgg(column='Cattle', aggfunc='sum'),
    Dairy=pd.NamedAgg(column='Dairy', aggfunc='sum'),
    Poultry=pd.NamedAgg(column='Poultry', aggfunc='sum'),
    Swine=pd.NamedAgg(column='Swine', aggfunc='sum'),
    Avg_Biogas_Production=pd.NamedAgg(column='Biogas Generation Estimate (cu-ft/day)', aggfunc='mean'),
    Total_Biogas_Production=pd.NamedAgg(column='Biogas Generation Estimate (cu-ft/day)', aggfunc='sum'),
    Avg_Waste=pd.NamedAgg(column='Total_Waste_kg/day', aggfunc='mean'),
    Total_Waste=pd.NamedAgg(column='Total_Waste_kg/day', aggfunc='sum'),
    Total_Electricity_Generated=pd.NamedAgg(column='Electricity Generated (kWh/yr)', aggfunc='sum'),
    Avg_Emission_Reduction=pd.NamedAgg(column='Total Emission Reductions (MTCO2e/yr)', aggfunc='mean'),
    Number_of_Digesters=pd.NamedAgg(column='Digester Type', aggfunc='nunique'),
    USDA_Funded_Projects=pd.NamedAgg(column='Awarded USDA Funding?', aggfunc=lambda x: (x == 'Yes').sum()),
    Most_Common_Use=pd.NamedAgg(column='Biogas End Use(s)', aggfunc=lambda x: x.value_counts().index[0] if not x.empty else None),
    Use_Types=pd.NamedAgg(column='Biogas End Use(s)', aggfunc=lambda x: ", ".join(x.unique()))
).reset_index()

state_grouped.index = range(1, len(state_grouped) + 1)

state_grouped = state_grouped.sort_values(by='Total_Projects', ascending=False)

state_grouped
# Out:
#              State  Total_Projects  Operational_Projects  \
# 3       California             144                    90
# 35       Wisconsin              52                    36
# 22        New York              48                    31
# 27    Pennsylvania              33                    30
# 32         Vermont              23                    14
# 10         Indiana              14                    11
# 16        Michigan              14                     8
# 23  North Carolina              13                     9
# 30           Texas              13                     6
# 11            Iowa              12                     7
# 17       Minnesota              12                     6
# 19        Missouri              11                    10
# 26          Oregon              10                     6
# 8            Idaho               8                     6
# 15   Massachusetts               8                     8
# 34      Washington               8                     8
# 29    South Dakota               7                     1
# 24            Ohio               7                     7
# 1          Arizona               7                     5
# 18     Mississippi               6                     4
# 5      Connecticut               5                     2
# 31            Utah               5                     4
# 6          Florida               4                     3
# 9         Illinois               4                     2
# 36         Wyoming               3                     1
# 14        Maryland               3                     2
# 7          Georgia               2                     1
# 4         Colorado               2                     1
# 33        Virginia               2                     1
# 28  South Carolina               2                     2
# 21        Nebraska               2                     0
# 12        Kentucky               2                     1
# 13           Maine               2                     1
# 25        Oklahoma               1                     1
# 2         Arkansas               1                     1
# 20         Montana               1                     1
#
#     Avg_Operational_Years  Total_Animals    Cattle      Dairy     Poultry  \
# 3                   4.965     883866.000 40000.000 836366.000       0.000
# 35                 13.608     676717.000     0.000 174717.000  500000.000
# 22                 13.133     215618.000     0.000  85618.000  130000.000
# 27                 16.545     280657.000  1130.000  18527.000  225000.000
# 32                 14.478      19865.000     0.000  19865.000       0.000
# 10                 12.129      69701.000  4800.000  60101.000       0.000
# 16                 12.571      61450.000     0.000  36450.000       0.000
# 23                 16.123     290440.000     0.000   1618.000   70000.000
# 30                 11.508     266730.000     0.000 106730.000       0.000
# 11                 16.433      49980.000  8650.000  28180.000       0.000
# 17                 12.133      49210.000     0.000  49210.000       0.000
# 19                  6.273     426455.000  2500.000      0.000       0.000
# 26                 14.700      49367.000     0.000  49367.000       0.000
# 8                  12.375      89900.000     0.000  89900.000       0.000
# 15                  7.125       3856.000    30.000   3826.000       0.000
# 34                 14.000      15300.000     0.000  15300.000       0.000
# 29                 10.029      26049.000     0.000  26049.000       0.000
# 24                 12.429    1220260.000     0.000   8260.000 1200000.000
# 1                   7.286      84514.000     0.000  84514.000       0.000
# 18                 18.000     481095.000     0.000    450.000  474000.000
# 5                  11.400       4555.000     0.000   4555.000       0.000
# 31                 13.600     461800.000     0.000   1950.000       0.000
# 6                  16.350      16309.000  5000.000  11309.000       0.000
# 9                  20.500      11800.000     0.000   2900.000       0.000
# 36                 18.733      29210.000     0.000   6210.000       0.000
# 14                 16.000      80801.000     0.000    801.000   80000.000
# 7                  15.000       1235.000     0.000   1135.000       0.000
# 4                  12.000      12600.000     0.000   7100.000       0.000
# 33                 20.500       4200.000     0.000   1200.000       0.000
# 28                 11.000     159600.000     0.000      0.000  150000.000
# 21                 17.000      35500.000 28000.000      0.000       0.000
# 12                 11.500     160030.000     0.000     30.000  160000.000
# 13                  6.000       6775.000     0.000   6775.000       0.000
# 25                 21.000      26500.000     0.000      0.000       0.000
# 2                  15.000       4200.000     0.000      0.000       0.000
# 20                 14.000        750.000     0.000    750.000       0.000
#
#         Swine  Avg_Biogas_Production  Total_Biogas_Production  Avg_Waste  \
# 3    7500.000             380835.713             54840342.600 203291.278
# 35   2000.000             562496.235             29249804.200 115295.731
# 22      0.000             315853.962             15160990.200  60889.833
# 27  36000.000             317507.594             10477750.600  25841.455
# 32      0.000             475550.226             10937655.200  29365.652
# 10   4800.000             618025.414              8652355.800 154531.000
# 16  25000.000             233790.600              3273068.400  97450.000
# 23 218822.000             496979.862              6460738.200  88878.615
# 30 160000.000             709280.738              9220649.600 340678.462
# 11  13150.000             689397.717              8272772.600  99739.167
# 17      0.000             602890.183              7234682.200 139428.333
# 19 423955.000             282767.382              3110441.200 197252.273
# 26      0.000             529961.800              5299618.000 167847.800
# 8       0.000             533259.850              4266078.800 382075.000
# 15      0.000             398250.925              3186007.400  16335.500
# 34      0.000             673724.550              5389796.400  65025.000
# 29      0.000             321992.857              2253950.000 126523.714
# 24  12000.000             454555.771              3181890.400  64120.000
# 1       0.000             857572.229              6003005.600 410496.571
# 18   6645.000             469179.267              2815075.600  15197.500
# 5       0.000             288177.160              1440885.800  30974.000
# 31 459850.000             488095.200              2440476.000 473110.000
# 6       0.000             492552.600              1970210.400 121126.500
# 9    8900.000             458135.000              1832540.000  35775.000
# 36  23000.000             405475.067              1216425.200 108713.333
# 14      0.000             222606.400               667819.200  11478.000
# 7     100.000             211370.000               422740.000  19545.000
# 4    5500.000             493768.100               987536.200 134450.000
# 33   3000.000             322575.400               645150.800  27900.000
# 28   9600.000             673685.200              1347370.400  30750.000
# 21   7500.000             569550.000              1139100.000 298750.000
# 12      0.000             382542.600               765085.200   7710.000
# 13      0.000             519983.700              1039967.400 115175.000
# 25  26500.000             646085.200               646085.200 132500.000
# 2    4200.000            1814400.000              1814400.000  21000.000
# 20      0.000              36000.000                36000.000  25500.000
#
#     Total_Waste  Total_Electricity_Generated  Avg_Emission_Reduction  \
# 3  29273944.000                137012880.000               52046.110
# 35  5995378.000                126095244.000               28322.061
# 22  2922712.000                110246031.600               19119.007
# 27   852768.000                 39012746.400                6686.620
# 32   675410.000                 31740123.800               21991.022
# 10  2163434.000                116120617.400               38964.995
# 16  1364300.000                 35632771.200               22797.924
# 23  1155422.000                 31592574.000               36463.441
# 30  4428820.000                 11315511.000              105448.570
# 11  1196870.000                 45026360.200               35689.985
# 17  1673140.000                 58566599.200               36083.311
# 19  2169775.000                 13924768.000               35902.599
# 26  1678478.000                 30247908.000               50458.884
# 8   3056600.000                 76271916.600              109324.851
# 15   130684.000                 27342086.800                5543.433
# 34   520200.000                 47619360.000               18849.833
# 29   885666.000                 15621453.000               36346.810
# 24   448840.000                 24674572.000               17070.667
# 1   2873476.000                 21901261.400              115048.690
# 18    91185.000                  3353990.000               23257.306
# 5    154870.000                  9109194.000               11960.636
# 31  2365550.000                 26168970.000               63904.728
# 6    484506.000                 12654340.000               33342.174
# 9    143100.000                  4266120.000               51127.621
# 36   326140.000                  2330520.400               13007.433
# 14    34434.000                   530000.000               15103.681
# 7     39090.000                   263840.000               52352.788
# 4    268900.000                  8299005.000               36394.518
# 33    55800.000                  3513700.000               15205.741
# 28    61500.000                  5361120.000                9959.778
# 21   597500.000                   730000.000               65496.092
# 12    15420.000                  3300000.000               75852.707
# 13   230350.000                  8894240.000               13294.444
# 25   132500.000                        0.000                9360.377
# 2     21000.000                        0.000                4482.755
# 20    25500.000                   372300.000                5499.563
#
#     Number_of_Digesters  USDA_Funded_Projects  \
# 3                     4                     9
# 35                    7                    28
# 22                    5                    14
# 27                    7                    13
# 32                    7                    12
# 10                    3                     2
# 16                    4                     3
# 23                    4                     5
# 30                    4                     0
# 11                    5                     3
# 17                    4                     4
# 19                    3                     1
# 26                    5                     2
# 8                     3                     2
# 15                    2                     4
# 34                    2                     5
# 29                    3                     0
# 24                    3                     7
# 1                     4                     1
# 18                    3                     3
# 5                     3                     1
# 31                    2                     0
# 6                     2                     0
# 9                     3                     1
# 36                    2                     0
# 14                    2                     1
# 7                     2                     1
# 4                     2                     0
# 33                    2                     1
# 28                    2                     0
# 21                    1                     1
# 12                    2                     0
# 13                    2                     1
# 25                    1                     0
# 2                     1                     0
# 20                    1                     1
#
#                       Most_Common_Use  \
# 3                                 CNG
# 35                       Pipeline Gas
# 22                       Cogeneration
# 27                       Cogeneration
# 32                       Cogeneration
# 10                                CNG
# 16                       Pipeline Gas
# 23                        Electricity
# 30                       Pipeline Gas
# 11                       Cogeneration
# 17                       Cogeneration
# 19                       Pipeline Gas
# 26                        Electricity
# 8                        Pipeline Gas
# 15                       Cogeneration
# 34                        Electricity
# 29                       Pipeline Gas
# 24                        Electricity
# 1                        Pipeline Gas
# 18  Cogeneration; Boiler/Furnace fuel
# 5                         Electricity
# 31                       Cogeneration
# 6                         Electricity
# 9                        Cogeneration
# 36                        Electricity
# 14   Electricity; Boiler/Furnace fuel
# 7                 Boiler/Furnace fuel
# 4                    Flared Full-time
# 33                       Cogeneration
# 28                       Cogeneration
# 21                Boiler/Furnace fuel
# 12                        Electricity
# 13                       Pipeline Gas
# 25                Boiler/Furnace fuel
# 2                    Flared Full-time
# 20   Electricity; Boiler/Furnace fuel
#
#                                             Use_Types
# 3   CNG, Electricity, Cogeneration; Refrigeration,...
# 35  Electricity; Boiler/Furnace fuel, Electricity,...
# 22  Electricity; Cogeneration, Electricity, No-Inf...
# 27                 Electricity, Cogeneration, No-Info
# 32  Cogeneration, Pipeline Gas, Boiler/Furnace fue...
# 10  Cogeneration, CNG, Cogeneration; CNG, Electric...
# 16  Pipeline Gas, Electricity; Boiler/Furnace fuel...
# 23  Boiler/Furnace fuel, Pipeline Gas, Electricity...
# 30  Pipeline Gas, CNG, Boiler/Furnace fuel, Cogene...
# 11  Cogeneration, Flared Full-time, Pipeline Gas, ...
# 17  Pipeline Gas, CNG, Electricity; Cogeneration, ...
# 19  Electricity, Flared Full-time, Pipeline Gas, B...
# 26  Electricity, Electricity; Cogeneration, Pipeli...
# 8             Pipeline Gas, Electricity, Cogeneration
# 15                          Cogeneration, Electricity
# 34                          Electricity, Cogeneration
# 29  Pipeline Gas, Electricity; Cogeneration; Boile...
# 24  Cogeneration, Electricity, Flared Full-time, E...
# 1        Pipeline Gas, CNG, Electricity, Cogeneration
# 18  Cogeneration; Boiler/Furnace fuel, Cogeneratio...
# 5   Cogeneration, Boiler/Furnace fuel, Electricity...
# 31            Cogeneration, Pipeline Gas, Electricity
# 6      Electricity, Pipeline Gas, Boiler/Furnace fuel
# 9                           Cogeneration, Electricity
# 36                          Pipeline Gas, Electricity
# 14  Electricity; Boiler/Furnace fuel, Boiler/Furna...
# 7   Boiler/Furnace fuel, Electricity; Boiler/Furna...
# 4                      Flared Full-time, Pipeline Gas
# 33                          Cogeneration, Electricity
# 28                          Cogeneration, Electricity
# 21             Boiler/Furnace fuel, Cogeneration; CNG
# 12                      Electricity, Flared Full-time
# 13                          Pipeline Gas, Electricity
# 25                                Boiler/Furnace fuel
# 2                                    Flared Full-time
# 20                   Electricity; Boiler/Furnace fuel

# %% [markdown]
# # <div style="padding: 30px; color:white; margin:10; font-size:150%; text-align:left; display:fill; border-radius:10px; background-color:#3b3745"><b><span style='color:#F1A424'>38 |</span></b> <b>Conclusions and Recommendations</b></div>

# %% [markdown]
# <div style="background-color: #e8f0ff; padding: 40px; border-radius: 20px; border: 8px double #1976D2; box-shadow: 0 4px 16px 0 rgba(0, 0, 0, 0.1);">
#     <h2 style="font-size: 36px; font-weight: bold; color: #0D47A1; text-align: center; font-family: 'Arial'; padding: 25px 0; margin-top: 20px; border-top: 6px solid #FFEB3B; border-bottom: 6px solid #FFEB3B; text-shadow: 1px 1px 3px #90caf9;">🌍 Comprehensive and In-depth Analysis of Livestock Farms with Biogas Facilities in the US 🌍</h2>
#     <ul style="font-size: 22px; font-family: 'Arial'; padding: 25px 40px; color: #212121; line-height: 2.5; background-color: #e3f2fd; border-radius: 15px; box-shadow: 0 3px 8px 0 rgba(0, 0, 0, 0.1);">
#         <li>🌿 <strong style="color: #1565C0; font-size: 24px; text-decoration: underline;">General Structure and Organization:</strong> The organization, regulatory compliance, and adaptability to local requirements of biogas farms in different states are pivotal for the effectiveness and economic viability of sustainable energy production.</li>
#         <li>⚙️ <strong style="color: #1565C0; font-size: 24px; text-decoration: underline;">Operation, Management, and Economic Factors:</strong> Business strategies, environmental sustainability, societal contributions, and economic efficiency are paramount. Competent management is the cornerstone for future achievements and financial sustainability in the biogas sector.</li>
#         <li>📈 <strong style="color: #1565C0; font-size: 24px; text-decoration: underline;">Impacts, Opportunities, and Profitability:</strong> The social, economic, and environmental ramifications of biogas farms pave the way for potential opportunities, risks, and economic profitability. Grasping these implications is crucial for sculpting future strategies, policies, and investment choices.</li>
#         <li>🔍 <strong style="color: #1565C0; font-size: 24px; text-decoration: underline;">Suggestions and Future Perspectives:</strong> The analysis underscores the necessity for enhanced control, regulation, innovation, and economic scrutiny in managing and operating biogas farms. Collaborations with business sectors, investors, governmental bodies, and other organizations can aid in making strategic investment choices and forging innovative solutions. Moreover, endorsing practices that mitigate environmental impacts and promote sustainable energy can bolster economic growth, generate employment opportunities, and uplift societal welfare.</li>
#     </ul>
#     <p style="font-size: 26px; color: #333; text-align: center; font-family: 'Arial'; padding: 25px; border-top: 4px dashed #1976D2; margin-top: 30px; background-color: #e1f5fe; border-radius: 15px; box-shadow: 0 3px 8px 0 rgba(0, 0, 0, 0.1);">Enhancing biogas facilities and practices can lead to a more sustainable and economically prosperous future.</p>
# </div>

# %% [markdown]
# <div style="text-align: center; padding: 60px; background: url('https://source.unsplash.com/800x600?energy') no-repeat center/cover; border: 5px solid #FFEB3B; border-radius: 35px; box-shadow: 0 15px 25px rgba(0, 0, 0, 0.2);">
#     <p style="font-size: 26px; margin-bottom: 35px; color: #000000; font-family: 'Arial', sans-serif; font-weight: bold; text-transform: uppercase; letter-spacing: 3px; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.5); animation: slide 3s infinite alternate;">
#         Click for the Next Analysis => U.S. Farms Biogas ML Prediction(Livestock)
#     </p>
#     <a href="https://www.kaggle.com/code/mehmetisik/u-s-farms-biogas-ml-prediction-livestock/notebook" target="_blank" style="text-decoration: none; display: inline-block; padding: 15px 30px; font-size: 24px; color: #673AB7; background-color: #FFFFFF; border-radius: 50px; transition: transform 0.3s ease; box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);">👉</a>
#     <style>
#         @keyframes pulsate {
#             0% { transform: scale(1); }
#             50% { transform: scale(1.08); }
#             100% { transform: scale(1); }
#         }
#         @keyframes slide {
#             0% { transform: translateX(-10px); }
#             100% { transform: translateX(10px); }
#         }
#         a:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.3);
#         }
#     </style>
# </div>

# %% [markdown]
# <style>
#   .link-card {
#     background-color: #f9f9f9;
#     border: 1px solid #e0e0e0;
#     padding: 15px;
#     border-radius: 8px;
#     margin: 10px 0;
#     display: flex;
#     align-items: center;
#     text-decoration: none;
#     color: #333;
#     transition: background-color 0.3s, transform 0.3s, box-shadow 0.3s;
#   }
#
#   .link-card:hover {
#     background-color: #f0f0f0;
#     transform: translateY(-5px);
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1); /* Hover efekti için gölge eklendi */
#   }
#
#   .link-icon {
#     font-size: 50px;
#     margin-right: 15px;
#   }
#
#   .link-text {
#     font-size: 20px; /* İsimlerin boyutunu 20px olarak güncelledim */
#     font-weight: bold; /* Kalın yazı tipi */
#   }
# </style>
#
# <a href="https://www.kaggle.com/mehmetisik/code" class="link-card">
#   <span class="link-icon">📊</span>
#   <span class="link-text">Mehmet ISIK's Notebook</span>
# </a>
